# %%
# !pip install gymnasium ale-py autorom
# Out:
# Requirement already satisfied: gymnasium in c:\users\zaria\anaconda3\lib\site-packages (1.2.3)
# Requirement already satisfied: ale-py in c:\users\zaria\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: autorom in c:\users\zaria\anaconda3\lib\site-packages (0.6.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\zaria\anaconda3\lib\site-packages (from gymnasium) (2.3.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\zaria\anaconda3\lib\site-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\zaria\anaconda3\lib\site-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\zaria\anaconda3\lib\site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: click in c:\users\zaria\anaconda3\lib\site-packages (from autorom) (8.2.1)
# Requirement already satisfied: requests in c:\users\zaria\anaconda3\lib\site-packages (from autorom) (2.32.5)
# Requirement already satisfied: colorama in c:\users\zaria\anaconda3\lib\site-packages (from click->autorom) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\zaria\anaconda3\lib\site-packages (from requests->autorom) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\zaria\anaconda3\lib\site-packages (from requests->autorom) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\zaria\anaconda3\lib\site-packages (from requests->autorom) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zaria\anaconda3\lib\site-packages (from requests->autorom) (2025.11.12)

# %%
# !AutoROM --accept-license
# Out:
# AutoROM will download the Atari 2600 ROMs.
# They will be installed to:
# 	C:\Users\zaria\anaconda3\Lib\site-packages\AutoROM\roms
#
# Existing ROMs will be overwritten.
# C:\Users\zaria\anaconda3\Lib\site-packages\AutoROM\AutoROM.py:264: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
# !pip install pygame
# Out:
# Requirement already satisfied: pygame in c:\users\zaria\anaconda3\lib\site-packages (2.6.1)

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\zaria\anaconda3\lib\site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in c:\users\zaria\anaconda3\lib\site-packages (from opencv-python) (2.3.5)

# %%
# %pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in c:\users\zaria\anaconda3\lib\site-packages (2.11.0)
# Requirement already satisfied: torchvision in c:\users\zaria\anaconda3\lib\site-packages (0.26.0)
# Requirement already satisfied: torchaudio in c:\users\zaria\anaconda3\lib\site-packages (2.11.0)
# Requirement already satisfied: filelock in c:\users\zaria\anaconda3\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\zaria\anaconda3\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in c:\users\zaria\anaconda3\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\zaria\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\zaria\anaconda3\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\zaria\anaconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\zaria\anaconda3\lib\site-packages (from torch) (2025.10.0)
# Requirement already satisfied: numpy in c:\users\zaria\anaconda3\lib\site-packages (from torchvision) (2.3.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\zaria\anaconda3\lib\site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\zaria\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\zaria\anaconda3\lib\site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import gymnasium as gym
import ale_py
import numpy as np
import cv2
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
import time
import torch
import torch.nn as nn
import torch.optim as optim

# %%
gym.register_envs(ale_py)

# Training env — RAM only, no rendering (rendering during training slows things down a lot)
env = gym.make("ALE/Freeway-v5", obs_type="ram")

# %%
# ---------------------------
# RAM MAP (verified against real game data)
# ---------------------------
# byte 14       = chicken Y position
#                  6   = bottom (start)
#                  174 = top (just before crossing)
#                  resets to 6 when crossing completes (env reward=1.0 fires)
# bytes 43-52   = car X position for each of the 10 lanes
#                  byte 43 = lane 0 (bottom), byte 52 = lane 9 (top)
# chicken X     = always 48 (horizontally fixed)
#
# Lane boundaries (from live RAM probing):
#   lane 0: y  6-21   (byte 43)
#   lane 1: y 22-37   (byte 44)
#   lane 2: y 38-53   (byte 45)
#   lane 3: y 54-69   (byte 46)
#   lane 4: y 70-85   (byte 47)
#   lane 5: y 86-101  (byte 48)
#   lane 6: y102-117  (byte 49)
#   lane 7: y118-133  (byte 50)
#   lane 8: y134-149  (byte 51)
#   lane 9: y150+     (byte 52)

CHICKEN_X = 48
DANGER_GAP = 30  # gap (in X units) below which a car is considered dangerous
                 # verified: cars with gap < ~30 reliably block upward movement

def get_lane(chicken_y):
    """Return which of the 10 lanes (0=bottom, 9=top) the chicken is in."""
    return max(0, min(9, (chicken_y - 6) // 16))

def get_car_gap(obs, chicken_y):
    """
    Return the horizontal distance between the chicken and the nearest car
    in the chicken's current lane.
    
    Cars move horizontally across each lane, so we read the X position
    from the correct RAM byte for the lane and compare to chicken_x=48.
    """
    lane = get_lane(chicken_y)
    car_x = int(obs[43 + lane])
    return abs(car_x - CHICKEN_X)

def is_in_danger(obs, chicken_y):
    """True if a car is dangerously close in the current lane."""
    return get_car_gap(obs, chicken_y) < DANGER_GAP

# %%
# ---------------------------
# NEURAL NETWORK
# ---------------------------
class MLP(nn.Module):
    def __init__(self, input_size, output_size):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, output_size)
        )
    def forward(self, x):
        return self.net(x)

# Add 3 for danger, block_up, and block_down flags
# 1. Define the sizes first
input_size = 128 + 3
output_size = env.action_space.n # This equals 3

# 2. Now create the model using those sizes
model = MLP(input_size, output_size)

# 3. Finally, set up the optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# Freeway specific constants
CHICKEN_X = 48
LANE_X_START_RAM = 33  # Car X positions are usually indices 33-42
DANGER_THRESHOLD = 20  # Distance in pixels to trigger 'Danger'

def is_in_danger(obs, chicken_y):
    current_lane = max(0, min(9, (chicken_y - 6) // 16))
    car_x = obs[LANE_X_START_RAM + current_lane]
    return 1.0 if abs(int(car_x) - int(CHICKEN_X)) < DANGER_THRESHOLD else 0.0

def is_block_up(obs, chicken_y):
    current_lane = max(0, min(9, (chicken_y - 6) // 16))
    if current_lane >= 9: return 0.0
    lane_above_x = obs[LANE_X_START_RAM + current_lane + 1]
    return 1.0 if abs(int(lane_above_x) - int(CHICKEN_X)) < DANGER_THRESHOLD else 0.0

def is_block_down(obs, chicken_y):
    current_lane = max(0, min(9, (chicken_y - 6) // 16))
    if current_lane <= 0: return 0.0
    lane_below_x = obs[LANE_X_START_RAM + current_lane - 1]
    return 1.0 if abs(int(lane_below_x) - int(CHICKEN_X)) < DANGER_THRESHOLD else 0.0
    
def get_augmented_state(obs, chicken_y):
    # 1. Calculate situational flags
    # Assuming is_in_danger is already written similar to the ones above
    danger = is_in_danger(obs, chicken_y) 
    b_up = is_block_up(obs, chicken_y)
    b_down = is_block_down(obs, chicken_y)
    
    # 2. Normalize RAM (0-1)
    normalized_obs = obs.astype(np.float32) / 255.0
    
    # 3. Create the 3 extra features
    extra_features = np.array([float(danger), float(b_up), float(b_down)], dtype=np.float32)
    
    # 4. Combine into a 131-length vector (128 + 3)
    return np.concatenate([normalized_obs, extra_features])

# %%
# ---------------------------
# TRAINING 
# ---------------------------
RESET_TRAINING   = True   # True = start fresh, False = resume from checkpoint

episodes         = 3      # set to 1000-5000 for real training
gamma            = 0.99   # discount factor — makes agent care about future rewards
entropy_coef     = 0.01   # keeps the agent exploring instead of locking in too early
checkpoint_every = 1  # save every episode
YOUR_UP_ACTION_INDEX = 1
YOUR_DOWN_ACTION_INDEX = 2
step = 0

episode_rewards = []
start_episode   = 0

# ---------------------------
# CHECKPOINT LOADING
# ---------------------------
if not RESET_TRAINING:
    try:
        checkpoint = torch.load("checkpoint.pth", weights_only=True)
        model.load_state_dict(checkpoint["model_state"])
        optimizer.load_state_dict(checkpoint["optimizer_state"])
        episode_rewards = checkpoint.get("episode_rewards", [])
        start_episode   = checkpoint["episode"] + 1
        print(f"Resuming from episode {start_episode}")
    except FileNotFoundError:
        print("No checkpoint found, starting fresh.")
else:
    print("RESET_TRAINING = True → Starting from scratch")

# ---------------------------
# TRAINING LOOP
# ---------------------------
test_state = get_augmented_state(obs, int(obs[14]))
print(f"Model Input Shape: {test_state.shape}") # Should say (131,)               deubg

for episode in range(start_episode, episodes):
    obs, _ = env.reset()

    log_probs = []
    rewards   = []
    entropies = []
    done      = False

    prev_y = int(obs[14])  # initialize to actual starting Y instead of None
    
    while not done:
        block_up = False
        block_down = False
        
        chicken_y = int(obs[14])
        current_lane = max(0, min(9, (chicken_y - 6) // 16))

        # 2. CREATE SMART INPUT (The "Brain" sees the cars now)
        # This uses the method we added to create the 131-length vector
        augmented_state = get_augmented_state(obs, chicken_y)
        state_input = torch.tensor(augmented_state, dtype=torch.float32).unsqueeze(0)

        # 3. AGENT DECIDES
        logits = model(state_input)
        probs = torch.softmax(logits, dim=1)
        dist = torch.distributions.Categorical(probs)
        action = dist.sample()
        log_prob = dist.log_prob(action) 
        entropy = dist.entropy()         
        
        # 4. ENVIRONMENT STEP
        prev_y = chicken_y # save to calculate delta after moving
        obs, env_reward, term, trunc, _ = env.step(action.item())
        done = term or trunc
        
        # 5. POST-STEP MATH (For Reward Logic)
        chicken_y = int(obs[14])
        delta = chicken_y - prev_y
        current_lane = max(0, min(9, (chicken_y - 6) // 16))
        
        # Calculate situational flags for the Reward Function
        car_x_current = int(obs[43 + current_lane])
        gap_current = abs(car_x_current - CHICKEN_X)
        danger = gap_current < DANGER_GAP
        
        lane_above_x = int(obs[43 + current_lane + 1]) if current_lane < 9 else None
        block_up = lane_above_x is not None and abs(lane_above_x - CHICKEN_X) < DANGER_GAP
        
        lane_below_x = int(obs[43 + current_lane - 1]) if current_lane > 0 else None
        block_down = lane_below_x is not None and abs(lane_below_x - CHICKEN_X) < DANGER_GAP

        # --------------------------------------------------------------------------------------
        
        if danger:
            if action.item() == 0: # Agent chose to NOOP/Wait
                reward = +1.0 
            elif action.item() == 1: # Agent tried to go UP into a car
                reward = -3.0
            else: # Agent went DOWN away from car
                reward = -0.5

        elif block_up:
            if action.item() == 1: # Tried to move UP into a car
                reward = -3.0
            elif action.item() == 0: # Smartly waiting for the gap above
                reward = +1.0
            else: # Moved down to get away from car above
                reward = -0.5

        elif block_down: # <--- Now this only triggers if Current and Above are safe
            if action.item() == 2: # Agent backed into a car. Very bad!
                reward = -4.0 
            elif delta > 0: # Moving away from the car below
                reward = +2.0
            else:
                reward = -0.1 # Staying still is okay, but not ideal

        else: 
            # FULLY CLEAR: No car here, above, or below.
            if env_reward == 1.0: 
                reward = 10.0 
            elif delta > 0: 
                reward = 2.0  
            elif delta < 0: 
                reward = -1.5 # Punish retreating if there's no car to run from
            else: 
                reward = -0.5 # Stalling penalty

        prev_y = chicken_y

        log_probs.append(log_prob)
        rewards.append(reward)
        entropies.append(entropy)
        if step % 10 == 0: # Print every 10 steps so it doesn't lag 
            print(f"Step: {step} | Lane: {current_lane} | CarX: {car_x_current} | Act: {action.item()} | Rew: {reward:.2f} | Danger: {danger}")
        # ----------------------------------------------------------------------------------------
        #step += 1                                                            # debug
        #print(f"Step {step} | Reward: {reward}")                          # debug
        #print(f"chicken_y: {chicken_y}, prev_y: {prev_y}")
        # ---------------------------------------------------------------------------------------

    # ---------------------------
    # DISCOUNTED RETURNS
    # ---------------------------
    # G_t = r_t + γ*r_{t+1} + γ²*r_{t+2} + ...
    # This gives credit to early actions (like waiting) that enabled
    # safe crossing steps later in the episode.
    returns = []
    G = 0.0
    for r in reversed(rewards):
        G = r + gamma * G
        returns.insert(0, G)

    returns = torch.tensor(returns, dtype=torch.float32)
    # Normalize: keeps loss scale stable regardless of episode length
    returns = (returns - returns.mean()) / (returns.std() + 1e-8)

    # ---------------------------
    # BASELINE
    # ---------------------------
    # Subtract recent average so the agent learns relative improvement,
    # not just whether the raw reward was positive
    baseline = float(np.mean(episode_rewards[-50:])) if len(episode_rewards) >= 50 else 0.0

    # ---------------------------
    # POLICY UPDATE
    # ---------------------------
    loss = torch.tensor(0.0, requires_grad=True)
    for lp, G_t, ent in zip(log_probs, returns, entropies):
        advantage = G_t - baseline
        loss = loss + (-lp * advantage) + (-entropy_coef * ent)

    optimizer.zero_grad()
    loss.backward()
    print(f"Episode {episode} Loss: {loss.item():.4f} | Returns Mean: {returns.mean():.4f}")  # debug
    # Gradient clipping: prevents one bad episode from wrecking the weights
    torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
    optimizer.step()

    total_reward = sum(rewards)
    episode_rewards.append(total_reward)

    if episode % checkpoint_every == 0:
                                      # Save after every episode
        print(f"Episode {episode:>5} | Reward: {total_reward:>8.2f}")
        torch.save({
            "episode": episode,
            "model_state": model.state_dict(),
            "optimizer_state": optimizer.state_dict(),
            "episode_rewards": episode_rewards,
        }, "checkpoint.pth")
        print(f"  → Checkpoint saved at episode {episode}")

torch.save(model.state_dict(), "freeway_mlp.pth")
print("\nTraining complete. Model saved to freeway_mlp.pth")
env.close()
# Out:
# RESET_TRAINING = True → Starting from scratch
# Model Input Shape: (131,)
# Step: 0 | Lane: 0 | CarX: 80 | Act: 2 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 64 | Act: 2 | Rew: -0.50 | Danger: True
# Step: 0 | Lane: 0 | CarX: 48 | Act: 1 | Rew: -3.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 48 | Act: 1 | Rew: -3.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 32 | Act: 1 | Rew: -3.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 16 | Act: 2 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 1 | CarX: 240 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 1 | CarX: 224 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 1 | CarX: 208 | Act: 0 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 1 | CarX: 192 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 1 | CarX: 176 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 1 | CarX: 160 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 1 | CarX: 144 | Act: 2 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 1 | CarX: 113 | Act: 0 | Rew: 1.00 | Danger: False
# Step: 0 | Lane: 1 | CarX: 97 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 1 | CarX: 81 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 1 | CarX: 65 | Act: 0 | Rew: 1.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 97 | Act: 2 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 97 | Act: 0 | Rew: 1.00 | Danger: False
# Step: 0 | Lane: 1 | CarX: 17 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 1 | CarX: 1 | Act: 0 | Rew: -0.10 | Danger: False
# Step: 0 | Lane: 0 | CarX: 49 | Act: 2 | Rew: -0.50 | Danger: True
# Step: 0 | Lane: 0 | CarX: 33 | Act: 0 | Rew: 1.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 33 | Act: 0 | Rew: 1.00 | Danger: True
# Step: 0 | Lane: 1 | CarX: 193 | Act: 1 | Rew: -3.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 1 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 241 | Act: 1 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 225 | Act: 0 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 225 | Act: 0 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 209 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 193 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 177 | Act: 1 | Rew: -3.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 161 | Act: 2 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 161 | Act: 0 | Rew: 1.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 145 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 114 | Act: 0 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 98 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 82 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 1 | CarX: 210 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 66 | Act: 2 | Rew: -0.50 | Danger: True
# Step: 0 | Lane: 0 | CarX: 50 | Act: 0 | Rew: 1.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 34 | Act: 0 | Rew: 1.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 18 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 18 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 2 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 242 | Act: 0 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 226 | Act: 2 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 210 | Act: 2 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 210 | Act: 0 | Rew: 1.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 194 | Act: 1 | Rew: -3.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 178 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 162 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 146 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 146 | Act: 1 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 115 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 99 | Act: 0 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 83 | Act: 2 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 67 | Act: 2 | Rew: -0.50 | Danger: True
# Step: 0 | Lane: 0 | CarX: 67 | Act: 1 | Rew: -3.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 51 | Act: 0 | Rew: 1.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 35 | Act: 1 | Rew: -3.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 19 | Act: 1 | Rew: -3.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 3 | Act: 0 | Rew: 1.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 3 | Act: 1 | Rew: -3.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 243 | Act: 2 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 227 | Act: 0 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 211 | Act: 2 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 195 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 195 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 179 | Act: 0 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 163 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 147 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 116 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 116 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 100 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 1 | CarX: 85 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 1 | CarX: 69 | Act: 0 | Rew: 1.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 52 | Act: 2 | Rew: -0.50 | Danger: True
# Step: 0 | Lane: 0 | CarX: 52 | Act: 1 | Rew: -3.00 | Danger: True
# Step: 0 | Lane: 1 | CarX: 21 | Act: 1 | Rew: -3.00 | Danger: True
# Step: 0 | Lane: 1 | CarX: 5 | Act: 1 | Rew: -3.00 | Danger: False
# Step: 0 | Lane: 1 | CarX: 245 | Act: 1 | Rew: -3.00 | Danger: False
# Step: 0 | Lane: 1 | CarX: 229 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 1 | CarX: 213 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 1 | CarX: 197 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 1 | CarX: 181 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 1 | CarX: 165 | Act: 0 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 1 | CarX: 149 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 1 | CarX: 118 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 1 | CarX: 102 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 1 | CarX: 86 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 1 | CarX: 70 | Act: 2 | Rew: -0.50 | Danger: True
# Step: 0 | Lane: 1 | CarX: 54 | Act: 0 | Rew: 1.00 | Danger: True
# Step: 0 | Lane: 1 | CarX: 38 | Act: 1 | Rew: -3.00 | Danger: True
# Step: 0 | Lane: 1 | CarX:
| Act: 2 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 3 | CarX: 104 | Act: 2 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 3 | CarX: 72 | Act: 1 | Rew: -3.00 | Danger: True
# Step: 0 | Lane: 3 | CarX: 40 | Act: 0 | Rew: 1.00 | Danger: True
# Step: 0 | Lane: 3 | CarX: 8 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 3 | CarX: 232 | Act: 0 | Rew: 1.00 | Danger: False
# Step: 0 | Lane: 3 | CarX: 200 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 3 | CarX: 168 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 3 | CarX: 121 | Act: 1 | Rew: -3.00 | Danger: False
# Step: 0 | Lane: 3 | CarX: 89 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 3 | CarX: 57 | Act: 1 | Rew: -3.00 | Danger: True
# Step: 0 | Lane: 3 | CarX: 25 | Act: 2 | Rew: -0.50 | Danger: True
# Step: 0 | Lane: 3 | CarX: 249 | Act: 0 | Rew: 1.00 | Danger: False
# Step: 0 | Lane: 2 | CarX: 146 | Act: 1 | Rew: -0.10 | Danger: False
# Step: 0 | Lane: 2 | CarX: 115 | Act: 2 | Rew: -4.00 | Danger: False
# Step: 0 | Lane: 2 | CarX: 99 | Act: 1 | Rew: -0.10 | Danger: False
# Step: 0 | Lane: 2 | CarX: 67 | Act: 0 | Rew: 1.00 | Danger: True
# Step: 0 | Lane: 1 | CarX: 10 | Act: 0 | Rew: 1.00 | Danger: False
# Step: 0 | Lane: 1 | CarX: 250 | Act: 1 | Rew: -3.00 | Danger: False
# Step: 0 | Lane: 1 | CarX: 234 | Act: 0 | Rew: -0.10 | Danger: False
# Step: 0 | Lane: 1 | CarX: 218 | Act: 0 | Rew: -0.10 | Danger: False
# Step: 0 | Lane: 0 | CarX: 6 | Act: 0 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 246 | Act: 2 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 230 | Act: 2 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 214 | Act: 1 | Rew: -3.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 214 | Act: 0 | Rew: 1.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 198 | Act: 2 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 182 | Act: 1 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 166 | Act: 0 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 150 | Act: 0 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 1 | CarX: 208 | Act: 1 | Rew: -3.00 | Danger: False
# Step: 0 | Lane: 1 | CarX: 192 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 103 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 87 | Act: 0 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 1 | CarX: 144 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 71 | Act: 2 | Rew: -0.50 | Danger: True
# Step: 0 | Lane: 1 | CarX: 97 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 39 | Act: 2 | Rew: -0.50 | Danger: True
# Step: 0 | Lane: 0 | CarX: 23 | Act: 0 | Rew: 1.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 7 | Act: 2 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 7 | Act: 2 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 247 | Act: 0 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 231 | Act: 0 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 215 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 199 | Act: 1 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 199 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 183 | Act: 0 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 167 | Act: 0 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 151 | Act: 0 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 120 | Act: 0 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 120 | Act: 0 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 104 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 88 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 72 | Act: 1 | Rew: -3.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 56 | Act: 0 | Rew: 1.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 56 | Act: 0 | Rew: 1.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 40 | Act: 0 | Rew: 1.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 24 | Act: 1 | Rew: -3.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 8 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 248 | Act: 0 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 248 | Act: 0 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 232 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 1 | CarX: 178 | Act: 1 | Rew: -3.00 | Danger: False
# Step: 0 | Lane: 1 | CarX: 162 | Act: 0 | Rew: 1.00 | Danger: False
# Step: 0 | Lane: 1 | CarX: 146 | Act: 0 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 1 | CarX: 115 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 1 | CarX: 99 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 152 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 121 | Act: 0 | Rew: 1.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 105 | Act: 2 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 105 | Act: 0 | Rew: 1.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 89 | Act: 0 | Rew: 1.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 73 | Act: 2 | Rew: -0.50 | Danger: True
# Step: 0 | Lane: 0 | CarX: 57 | Act: 1 | Rew: -3.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 41 | Act: 2 | Rew: -0.50 | Danger: True
# Step: 0 | Lane: 0 | CarX: 41 | Act: 1 | Rew: -3.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 25 | Act: 0 | Rew: 1.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 9 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 249 | Act: 0 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 233 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 233 | Act: 0 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 217 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 201 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 185 | Act: 2 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 169 | Act: 1 | Rew: -3.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 169 | Act: 1 | Rew: -3.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 153 | Act: 0 | Rew: 1.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 122 | Act: 0 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 106 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 90 | Act: 0 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 90 | Act: 0 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 74 | Act: 0 | Rew: 1.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 58 | Act: 0 | Rew: 1.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 42 | Act: 2 | Rew: -0.50 | Danger: True
# Step: 0 | Lane: 0 | CarX: 26 | Act: 1 | Rew: -3.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 26 | Act: 2 | Rew: -0.50 | Danger: True
# Step: 0 | Lane: 0 | CarX: 10 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 250 | Act: 1 | Rew: 2.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 234 | Act: 2 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 218 | Act: 1 | Rew: -3.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 218 | Act: 2 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 96 | Act: 0 | Rew: 1.00 | Danger: False
# Step: 0 | Lane: 0 | CarX: 80 | Act: 0 | Rew: -0.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 64 | Act: 0 | Rew: 1.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 48 | Act: 0 | Rew: 1.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 48 | Act: 2 | Rew: -0.50 | Danger: True
# Step: 0 | Lane: 0 | CarX: 32 | Act: 0 | Rew: 1.00 | Danger: True
# Step: 0 | Lane: 0 | CarX: 16 | Act: 2 | Rew: -1.50 | Danger: False
# Step: 0 | Lane: 0 | CarX: 0 | Act: 2 | Rew: -0.50 | Danger: False
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 62
#      59 state_input = torch.tensor(augmented_state, dtype=torch.float32).unsqueeze(0)
#      61 # 3. AGENT DECIDES
# ---> 62 logits = model(state_input)
#      63 probs = torch.softmax(logits, dim=1)
#      64 dist = torch.distributions.Categorical(probs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# Cell In[23], line 15, in MLP.forward(self, x)
#      14 def forward(self, x):
# ---> 15     return self.net(x)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\torch\nn\modules\container.py:253, in Sequential.forward(self, input)
#     249 """
#     250 Runs the forward pass.
#     251 """
#     252 for module in self:
# --> 253     input = module(input)
#     254 return input
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\torch\nn\modules\linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
# ---------------------------
# TRAINING PROGRESS PLOT
# ---------------------------
# Raw reward per episode + 50-ep smoothed average.
# Look for:
#   - Upward trend = agent improving
#   - Plateau early = increase entropy_coef to keep exploring
#   - Reward spikes = crossing bonuses kicking in (good!)
# Assuming episode_rewards is your list of rewards per episode

# Load your checkpoint
checkpoint = torch.load("checkpoint.pth")

# Extract the episode_rewards list
episode_rewards = checkpoint["episode_rewards"]

# Set your smoothing window
window = 50

# Plotting with your actual data
if len(episode_rewards) >= 2:
    current_window = min(window, len(episode_rewards))
    if len(episode_rewards) >= current_window:
        smoothed = np.convolve(episode_rewards, np.ones(current_window)/current_window, mode='valid')
        x_vals = list(range(current_window - 1, len(episode_rewards)))
        fig, ax = plt.subplots(figsize=(12, 4))
        ax.plot(episode_rewards, alpha=0.25, color='steelblue', label='Raw reward')
        ax.plot(x_vals, smoothed, color='steelblue', linewidth=10, label=f'{current_window}-ep average')
    else:
        # Not enough data for smoothing; just plot raw rewards
        fig, ax = plt.subplots(figsize=(12, 4))
        ax.plot(episode_rewards, alpha=0.25, color='steelblue', label='Raw reward')
    ax.set_xlabel('Episode')
    ax.set_ylabel('Total Reward')
    ax.set_title('Training Progress')
    ax.legend()
    plt.tight_layout()
    plt.show()
else:
    print("Run more episodes to see a meaningful plot.")

# %%
# ---------------------------
# PLAY LOOP
# ---------------------------
# Two environments in lockstep:
#   env_vis = RGB frames for display
#   env_ram = RAM observations for the model
# Same seed + joint reset keeps them in sync.

env_vis = gym.make("ALE/Freeway-v5", render_mode="human")
env_ram = gym.make("ALE/Freeway-v5", obs_type="ram")

obs_vis, _ = env_vis.reset(seed=42)
obs_ram, _ = env_ram.reset(seed=42)

model.load_state_dict(torch.load("freeway_mlp.pth", weights_only=True))
model.eval()
#rint("Model loaded. Summary:", model)            # debug
#print("Observation RAM shape:", obs_ram.shape)
#print("Observation RAM sample:", obs_ram[:5])  # print first few values

while True:
    ram_input = torch.tensor(
        np.array(obs_ram, dtype=np.float32) / 255.0
    ).unsqueeze(0)
    
    #print("RAM input tensor:", ram_input)  # debug
    #print("RAM input shape:", ram_input.shape)
    #output = model(ram_input)
    #print("Model output:", output)
    #print("Predicted action:", torch.argmax(output, dim=1).item())
    #action = torch.argmax(output, dim=1).item()
    # -------------------------------------------------------------------------debug up there
    with torch.no_grad():
        action = torch.argmax(model(ram_input), dim=1).item()

    obs_vis, _, term1, trunc1, _ = env_vis.step(action)
    obs_ram, _, term2, trunc2, _ = env_ram.step(action)

    frame_bgr = cv2.cvtColor(obs_vis.copy(), cv2.COLOR_RGB2BGR)
    cv2.imshow("Freeway AI", frame_bgr)
    time.sleep(0.03)
    

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

    #print(f"Action taken: {action}") #                  dubug
    #print("Observation RAM:", obs_ram)
    
    if term1 or trunc1 or term2 or trunc2:
        obs_vis, _ = env_vis.reset(seed=42)
        obs_ram, _ = env_ram.reset(seed=42)

env_vis.close()
env_ram.close()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 36
#      33 with torch.no_grad():
#      34     action = torch.argmax(model(ram_input), dim=1).item()
# ---> 36 obs_vis, _, term1, trunc1, _ = env_vis.step(action)
#      37 obs_ram, _, term2, trunc2, _ = env_ram.step(action)
#      39 frame_bgr = cv2.cvtColor(obs_vis.copy(), cv2.COLOR_RGB2BGR)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\gymnasium\wrappers\common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\gymnasium\core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\gymnasium\wrappers\common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\ale_py\env.py:305, in AtariEnv.step(self, action)
#     303 reward = 0.0
#     304 for _ in range(frameskip):
# --> 305     reward += self.ale.act(action_idx, strength)
#     307 is_terminal = self.ale.game_over(with_truncation=False)
#     308 is_truncated = self.ale.game_truncated()
#
# KeyboardInterrupt:
